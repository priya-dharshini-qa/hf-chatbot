# %%
#install dependencies
# %pip install huggingface_hub

# %%
#API key
import os
HF_TOKEN = os.environ.get("HF_TOKEN")

# %%
#Initialise the model & API key
from huggingface_hub import InferenceClient
client = InferenceClient(
    model="meta-llama/Llama-3.1-8B-Instruct",  # a model that works on free tier
    token=HF_TOKEN
)

# %%
#actual chatbot code
from huggingface_hub import InferenceClient
import os

client = InferenceClient(
    provider="novita",                    # ✅ Novita provider
    api_key=os.environ["HF_TOKEN"]
)

conversation_history = [
    {"role": "system", "content": "You are a helpful assistant."}
]

def chat_hf(user_message):
    conversation_history.append({"role": "user", "content": user_message})

    response = client.chat.completions.create(
        model="meta-llama/Llama-3.1-8B-Instruct",   # ✅ Supported by Novita
        messages=conversation_history,
        max_tokens=100,
        temperature=0.7
    )

    reply = response.choices[0].message.content
    conversation_history.append({"role": "assistant", "content": reply})
    return reply

# Run the chatbot
print("Chatbot ready! Type 'quit' to exit.\n")

while True:
    user_input = input("You: ")
    if user_input.lower() in ["quit", "exit"]:
        print("Goodbye!")
        break
    print(f"Bot: {chat_hf(user_input)}\n")
# Out:
# Chatbot ready! Type 'quit' to exit.
#
# Bot: The answer is 2.
#
# Bot: We had 2 as the answer, and now we're adding 5 to it.
#
# 2 + 5 = 7
#
# Bot: Quantum computing is a type of computing that uses the principles of quantum mechanics to perform calculations and operations on data. Unlike classical computers, which use bits to process information, quantum computers use quantum bits or qubits.
#
# Qubits are unique because they can exist in multiple states simultaneously, known as a superposition. This allows for an exponential increase in processing power compared to classical computers.
#
# Some key features of quantum computing include:
#
# 1. **Superposition**: Qubits can be in multiple states at the same
#
# Bot: The last number was 7, and we're multiplying it by 10.
#
# 7 × 10 = 70
#
# Bot: It seems like you forgot to ask a question. If you'd like to ask something or continue the conversation, I'm here to help.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 31
#      27 # Run the chatbot
#      28 print("Chatbot ready! Type 'quit' to exit.\n")
#      29
#      30 while True:
# ---> 31     user_input = input("You: ")
#      32     if user_input.lower() in ["quit", "exit"]:
#      33         print("Goodbye!")
#      34         break
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
