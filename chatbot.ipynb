# %%
#install dependencies
# %pip install huggingface_hub

# %%
#API key
import os
HF_TOKEN = os.environ.get("HF_TOKEN")

# %%
#Initialise the model & API key
from huggingface_hub import InferenceClient
client = InferenceClient(
    model="meta-llama/Llama-3.1-8B-Instruct",  # a model that works on free tier
    token=HF_TOKEN
)

# %%
#actual chatbot code
from huggingface_hub import InferenceClient
import os

client = InferenceClient(
    provider="novita",                    # ✅ Novita provider
    api_key=os.environ["HF_TOKEN"]
)

conversation_history = [
    {"role": "system", "content": "You are a helpful assistant."}
]

def chat_hf(user_message):
    conversation_history.append({"role": "user", "content": user_message})

    response = client.chat.completions.create(
        model="meta-llama/Llama-3.1-8B-Instruct",   # ✅ Supported by Novita
        messages=conversation_history,
        max_tokens=500,
        temperature=0.7
    )

    reply = response.choices[0].message.content
    conversation_history.append({"role": "assistant", "content": reply})
    return reply

# Run the chatbot
print("Chatbot ready! Type 'quit' to exit.\n")

while True:
    user_input = input("You: ")
    if user_input.lower() in ["quit", "exit"]:
        print("Goodbye!")
        break
    reply = chat_hf(user_input)
    print(f"You: {user_input}")
    print(f"Bot: {reply}\n")
# Out:
# Chatbot ready! Type 'quit' to exit.
#
# You: 1=1=?
# Bot: It seems like a simple equation. However, you've left the right-hand side empty.
#
# Can you complete the equation with the right-hand side?
#
# You: what is chatbot
# Bot: A chatbot is a type of computer program that uses artificial intelligence (AI) to simulate human-like conversations with users. It's also known as a conversational AI, talkbot, or bot.
#
# Chatbots use natural language processing (NLP) to understand and respond to user inputs, such as text or voice commands. They can be integrated into various platforms, including messaging apps, websites, mobile apps, and voice assistants like Alexa or Google Assistant.
#
# Chatbots can perform a range of tasks, including:
#
# 1. Answering frequently asked questions (FAQs)
# 2. Providing customer support
# 3. Conducting simple transactions
# 4. Recommending products or services
# 5. Engaging in conversation and entertainment
#
# ...
